# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
import tensorflow as tf
import pandas as pd
import datetime
import numpy as np
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
# !rm -rf ./logs/ 

train_all = pd.read_csv("tsaih_train_all.csv",na_values=['null'],index_col=False, header=None, infer_datetime_format=True)
train_all
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.002390 -0.002091  0.001010 -0.002171  0.000091  0.000114  0.000548
# 1   -0.002484 -0.002170  0.000752  0.000790  0.000086  0.000113  0.000554
# 2   -0.002752 -0.002469  0.000998  0.002989  0.000087  0.000114  0.000555
# 3   -0.002925 -0.002657  0.001240  0.003282  0.000092  0.000116  0.000563
# 4   -0.003050 -0.002783  0.001476  0.000550  0.000090  0.000116  0.000602
# ..        ...       ...       ...       ...       ...       ...       ...
# 475 -0.001887 -0.001211  0.000661 -0.000645  0.001544  0.001539  0.000090
# 476 -0.001840 -0.001211  0.000724 -0.000030  0.001526  0.001546  0.000089
# 477 -0.002028 -0.001431  0.000122  0.002421  0.001551  0.001550  0.000089
# 478 -0.001761 -0.001289  0.000528  0.000795  0.001549  0.001558  0.000090
# 479 -0.001698 -0.001352  0.000317  0.000710  0.001572  0.001572  0.000102
#
#            7         8         9         10        11  12
# 0    0.000718  0.000021  0.000004  0.001011  0.000984  -1
# 1    0.000679  0.000020  0.000003  0.001013  0.000981  -1
# 2    0.000621  0.000021  0.000004  0.001038  0.000988  -1
# 3    0.000485  0.000026  0.000006  0.001069  0.001009   1
# 4    0.000446  0.000026  0.000007  0.001051  0.001009   1
# ..        ...       ...       ...       ...       ...  ..
# 475  0.000369  0.001451  0.000685  0.001134  0.001385   1
# 476  0.000272  0.001480  0.000644  0.001229  0.001433   1
# 477  0.000233  0.001513  0.000688  0.001356  0.001481   1
# 478  0.000233  0.001557  0.000923  0.001439  0.001572   1
# 479  0.000252  0.001572  0.000633  0.001285  0.001546   1
#
# [480 rows x 13 columns]

# %%
dataVolume, inputSize = train_all.shape
hiddenSize = 15
print("Number of input node, m =", inputSize)
print("Number of hidden node, p =", hiddenSize)
print("Number of inputs, q =", dataVolume)
# Out:
# Number of input node, m = 13
# Number of hidden node, p = 15
# Number of inputs, q = 480

# %%
def conditionL(y_data, dataVolume):
    a = y_data[np.random.randint(dataVolume)]
    b = y_data[np.random.randint(dataVolume)]
    while a <= b:
        a = y_data[np.random.randint(dataVolume)]
        b = y_data[np.random.randint(dataVolume)]
    return a, b

def add_layer(inputs, input_size, output_size, activation_function=None):
    with tf.name_scope("layer"):
        with tf.name_scope("weight"):
            Weights = tf.Variable(tf.random_normal([input_size, output_size]))
        with tf.name_scope("threshold"):
            threshold = tf.Variable(tf.zeros([1, output_size]) + 0.1)
        with tf.name_scope("Wx_plus_b"):
            Wx_plus_b = tf.matmul(inputs, Weights) + threshold
        if activation_function is None:
            outputs = Wx_plus_b
        else:
            outputs = activation_function(Wx_plus_b)
        return outputs, Weights, threshold

LearningRate = 0.01
RegularizationTerm = 0.001
LearningRateArr = []
ErrorArr = []

#Step 1
HiddenLOutput, HWeights, HThreshold = add_layer(xs, inputSize, hiddenSize, activation_function = tf.tanh)
OutputLOutput, OWeights, OThreshold = add_layer(HiddenLOutput, hiddenSize, 1, activation_function = None)


#Forwarding (Activation Function & Regulation term)
with tf.name_scope("loss"):
    LossFunction = tf.reduce_mean(tf.reduce_sum(tf.square(yc - OutputLOutput)
                  , reduction_indices=[1])) + tf.math.multiply(RegularizationTerm
                  , tf.reduce_sum(tf.square(OWeights)) + tf.reduce_sum(tf.square(HWeights)) + tf.reduce_sum(tf.square(HThreshold))+tf.reduce_sum(tf.square(OThreshold)))

#Backwarding by Gradient
#Set adjusted Learning Goal
with tf.name_scope("train"):
    train = tf.train.GradientDescentOptimizer(LearningRate).minimize(LossFunction)

#LTS
residual = tf.square(yc - OutputLOutput)
def lts(n, lts_x_error, x_data, y_data):
    lts_x_data = []
    lts_y_data = []
    #index_list = []
    for i in range(n):
        index = np.where(lts_x_error == lts_x_error.min())
        #index_list.append(index[0])
        lts_x_error[index[0]] = lts_x_error.max() + 1
        lts_x_data.extend(x_data[index[0]])
        lts_y_data.extend(y_data[index[0]])
    return lts_x_data, lts_y_data

#Learning Goal
LearningGoalFunction = tf.reduce_mean(tf.reduce_sum(tf.math.abs(yc - OutputLOutput), reduction_indices=[1]))

init = tf.global_variables_initializer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-da8629b90829> in <module>
#      27
#      28 #Step 1
# ---> 29 HiddenLOutput, HWeights, HThreshold = add_layer(xs, inputSize, hiddenSize, activation_function = tf.tanh)
#      30 OutputLOutput, OWeights, OThreshold = add_layer(HiddenLOutput, hiddenSize, 1, activation_function = None)
#      31
#
# NameError: name 'xs' is not defined

# %%
with tf.name_scope("inputs"):
    x_data = train_all.iloc[:,0:12].to_numpy()
    y_data = train_all.iloc[:,12:13].to_numpy()
    xs = tf.placeholder(tf.float64, name = "x_input")
    yc = tf.placeholder(tf.int64, name = "y_input")
    a, b = conditionL(y_data, dataVolume)

print("a, b =", a, ",", b)
#x_data
#y_data
x_data[0:n]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ca355f60a83d> in <module>
#       2     x_data = train_all.iloc[:,0:12].to_numpy()
#       3     y_data = train_all.iloc[:,12:13].to_numpy()
# ----> 4     xs = tf.placeholder(tf.float64, name = "x_input")
#       5     yc = tf.placeholder(tf.int64, name = "y_input")
#       6     a, b = conditionL(y_data, dataVolume)
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
sess = tf.Session()
writer = tf.summary.FileWriter("./showmethetensorboard", sess.graph)
sess.run(init)

#Step1. Pick up n cases to set up an acceptable SLFN with 1 hidden node
n = 1
sess.run(LossFunction, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
sess.run(train, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
sess.run(OutputLOutput, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
lts_x_error = sess.run(residual, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
lts_x_data, lts_y_data = lts(n, lts_x_error, x_data, y_data)
print("Round:", n, "\nInitial model.")
n = n + 1

#Step1.1 Initial SLFN model
sess.run(train, feed_dict={xs: lts_x_data, yc: lts_y_data})
Output = sess.run(OutputLOutput, feed_dict={xs: lts_x_data, yc: lts_y_data})
Error = sess.run(LossFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
iniHWeights = sess.run(HWeights, feed_dict={xs: lts_x_data, yc: lts_y_data})
iniHThreshold = sess.run(HThreshold, feed_dict={xs: lts_x_data, yc: lts_y_data})
iniOWeights = sess.run(OWeights, feed_dict={xs: lts_x_data, yc: lts_y_data})
iniOThreshold = sess.run(OThreshold, feed_dict={xs: lts_x_data, yc: lts_y_data}) 

#Step2. Add another case into I(n)
  #Stopping Criteria1: n = dataVolume
while n <= dataVolume:
    #Save previous error, weights & thresholds
    preError = Error
    preHWeights = sess.run(HWeights, feed_dict={xs: lts_x_data, yc: lts_y_data})
    preHThreshold = sess.run(HThreshold, feed_dict={xs: lts_x_data, yc: lts_y_data})
    preOWeights = sess.run(OWeights, feed_dict={xs: lts_x_data, yc: lts_y_data})
    preOThreshold = sess.run(OThreshold, feed_dict={xs: lts_x_data, yc: lts_y_data})    
    lts_x_error = sess.run(residual, feed_dict={xs: x_data, yc: y_data})
    lts_x_data, lts_y_data = lts(n, lts_x_error, x_data, y_data)
    #debugging
    print("Round:", n)
    #print(lts_x_data)
    #print(lts_y_data)
    #print(preError, preHThreshold, preHWeights, preOThreshold, preOWeights, sep = "\n")
    n = n + 1

#Step3. Whether I(n) satisfying the Learning Goal?
    LearningGoal = sess.run(LearningGoalFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
    #Stopping Criteria2: LearningGoal <= 0.1
    if (LearningGoal <= 0.1) | (a > b):
        print("No out-lier.")
        continue
        
#Step4. Weight-Tuning Mechanism: Creating a new SLFN model
    else:
        print("Out-lier detection!")
        time = 0
        #Step5-1. Stopping Criteria(1): LearningGoal <= 0.1
        while (LearningGoal > 0.1) | (a < b):
            time = time + 1
            #train a new model
            sess.run(train, feed_dict={xs: lts_x_data, yc: lts_y_data})
            Output = sess.run(OutputLOutput, feed_dict={xs: lts_x_data, yc: lts_y_data})
            if Error > preError:

        #Step5-2. Stopping Criteria(2): Learning-rate
                if LearningRate < 0.01:
                    print(time, "Fail: due to tiny learning rate(", LearningRate, ")")
                    #restore weights & thresholds (Step.6 Cramming & Softening Mechanism... to be updated)
                    #sess.run(tf.assign(HWeights, iniHWeights))
                    #sess.run(tf.assign(HThreshold, iniHThreshold))
                    #sess.run(tf.assign(OWeights, iniOWeights))
                    #sess.run(tf.assign(OThreshold, iniOThreshold)) 
                    break
                else:
                    print(time, "Keep learning at learning rate =", LearningRate)
                    LearningRate = LearningRate * 0.7
                    sess.run(tf.assign(HWeights, preHWeights))
                    sess.run(tf.assign(HThreshold, preHThreshold))
                    sess.run(tf.assign(OWeights, preOWeights))
                    sess.run(tf.assign(OThreshold, preOThreshold)) 

            else:
                LearningRate = LearningRate * 1.2
                Error = sess.run(LossFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
            
            a, b = conditionL(Output)
            
        print(time, "Stop, Learning Goal =", LearningGoal)
        sess.run(train, feed_dict={xs: lts_x_data, yc: lts_y_data})
        Output = sess.run(OutputLOutput, feed_dict={xs: lts_x_data, yc: lts_y_data})
        Error = sess.run(LossFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
        LearningGoal = sess.run(LearningGoalFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
        
            #debugging
        #Weights = sess.run(OWeights, feed_dict={xs: lts_x_data, yc: lts_y_data})
        #LearningGoal = sess.run(LearningGoalFunction, feed_dict={xs: lts_x_data, yc: lts_y_data})
        #LearningRateArr.append(LearningRate)
        #ErrorArr.append(Error)
        #print("Time =", time, " Learning Rate =", LearningRate, " Error =", Error)
        #print("Weights =", Weights)
        #print("Output =", Output)
        #LearningRateGraph = plt.plot(LearningRateArr)
        #print("Learning Rate", LearningRateGraph)
        #ErrorGraph = plt.plot(ErrorArr)
        #print("Error", ErrorGraph)

writer.close()
sess.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'inputs_11/y_input' with dtype float
# 	 [[{{node inputs_11/y_input}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-88-67e1d788a8d7> in <module>
#       5 #Step1. Pick up n cases to set up an acceptable SLFN with 1 hidden node
#       6 n = 1
# ----> 7 sess.run(LossFunction, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
#       8 sess.run(train, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
#       9 sess.run(OutputLOutput, feed_dict={xs: x_data[0:n], yc: y_data[0:n]})
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'inputs_11/y_input' with dtype float
# 	 [[node inputs_11/y_input (defined at <ipython-input-67-545db60faa17>:5) ]]
#
# Caused by op 'inputs_11/y_input', defined at:
#   File "/Users/user/anaconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/user/anaconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/user/anaconda3/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/user/anaconda3/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/user/anaconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-67-545db60faa17>", line 5, in <module>
#     yc = tf.placeholder(tf.float32, name = "y_input")
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py", line 2077, in placeholder
#     return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 5791, in placeholder
#     "Placeholder", dtype=dtype, shape=shape, name=name)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "/Users/user/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InvalidArgumentError (see above for traceback): You must feed a value for placeholder tensor 'inputs_11/y_input' with dtype float
# 	 [[node inputs_11/y_input (defined at <ipython-input-67-545db60faa17>:5) ]]

# %%
#Go to Terminal
#enter:
    #cd ~user
    #tensorboard --logdir=showmethetensorboard --host=127.0.0.1
#Copy the URL to your browser

# %%
# Out:
# 480

# %%
#y_data[y_data==1]=0
#y_data[np.random.randint()]
#

g
# Out:
# array([1])
